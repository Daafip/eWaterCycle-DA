
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-10-01T00:00:00Z',
#                     end_time='1998-11-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='01620500_lump_cida_forcing_leap.txt',
#                     pr='HBV_forcing_CAMELS_2024-03-12 15_13.nc',
#                     pev='HBV_forcing_CAMELS_2024-03-12 15_13.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240312_141325/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1998-11-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='01620500_lump_cida_forcing_leap.txt',
#                 pr='HBV_forcing_CAMELS_2024-03-12 15_13.nc',
#                 pev='HBV_forcing_CAMELS_2024-03-12 15_13.nc',
#                 alpha=1.26,
#                 test_data_bool=False,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '3.3881523624654797,0.9628640905728398,730.7422187013755,3.3108416696115124,0.09073306062985803,9.'
#                     '601978646101843,0.0824680484546028,0.005130903839114647'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-10-01T00:00:00Z',
#                     end_time='1998-11-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='01620500_lump_cida_forcing_leap.txt',
#                     pr='HBV_forcing_CAMELS_2024-03-12 15_13.nc',
#                     pev='HBV_forcing_CAMELS_2024-03-12 15_13.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240312_141327/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1998-11-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='01620500_lump_cida_forcing_leap.txt',
#                 pr='HBV_forcing_CAMELS_2024-03-12 15_13.nc',
#                 pev='HBV_forcing_CAMELS_2024-03-12 15_13.nc',
#                 alpha=1.26,
#                 test_data_bool=False,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '2.6134609721339883,0.5181229621501353,794.8195279432987,2.35792977707036,0.1030235411002997,9.047'
#                     '674012328596,0.014653840492257,0.0002885417637033307'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-10-01T00:00:00Z',
#                     end_time='1998-11-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='01620500_lump_cida_forcing_leap.txt',
#                     pr='HBV_forcing_CAMELS_2024-03-12 15_13.nc',
#                     pev='HBV_forcing_CAMELS_2024-03-12 15_13.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240312_141328/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1998-11-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='01620500_lump_cida_forcing_leap.txt',
#                 pr='HBV_forcing_CAMELS_2024-03-12 15_13.nc',
#                 pev='HBV_forcing_CAMELS_2024-03-12 15_13.nc',
#                 alpha=1.26,
#                 test_data_bool=False,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '2.4658027475835143,0.446706513824281,742.9440911453531,0.7940298689350203,0.16936900349218878,9.9'
#                     '4665800941148,0.021522014594569518,0.00692229712792825'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-10-01T00:00:00Z',
#                     end_time='1998-11-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='01620500_lump_cida_forcing_leap.txt',
#                     pr='HBV_forcing_CAMELS_2024-03-12 15_13.nc',
#                     pev='HBV_forcing_CAMELS_2024-03-12 15_13.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240312_141330/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1998-11-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='01620500_lump_cida_forcing_leap.txt',
#                 pr='HBV_forcing_CAMELS_2024-03-12 15_13.nc',
#                 pev='HBV_forcing_CAMELS_2024-03-12 15_13.nc',
#                 alpha=1.26,
#                 test_data_bool=False,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '0.6695984603678156,0.8855580537207406,67.87707245259631,2.4864052720683847,0.09765912109775247,2.'
#                     '934383462220697,0.07563856575586883,0.00496064863908341'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-10-01T00:00:00Z',
#                     end_time='1998-11-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='01620500_lump_cida_forcing_leap.txt',
#                     pr='HBV_forcing_CAMELS_2024-03-12 15_13.nc',
#                     pev='HBV_forcing_CAMELS_2024-03-12 15_13.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240312_141331/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1998-11-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='01620500_lump_cida_forcing_leap.txt',
#                 pr='HBV_forcing_CAMELS_2024-03-12 15_13.nc',
#                 pev='HBV_forcing_CAMELS_2024-03-12 15_13.nc',
#                 alpha=1.26,
#                 test_data_bool=False,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '6.714656446188688,0.7924087492439731,691.2293942505668,1.392341874169004,0.0988641036530396,1.506'
#                     '0288581635555,0.02554067227151196,0.007679819044452723'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-10-01T00:00:00Z',
#                     end_time='1998-11-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='01620500_lump_cida_forcing_leap.txt',
#                     pr='HBV_forcing_CAMELS_2024-03-12 15_13.nc',
#                     pev='HBV_forcing_CAMELS_2024-03-12 15_13.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240312_141333/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1998-11-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='01620500_lump_cida_forcing_leap.txt',
#                 pr='HBV_forcing_CAMELS_2024-03-12 15_13.nc',
#                 pev='HBV_forcing_CAMELS_2024-03-12 15_13.nc',
#                 alpha=1.26,
#                 test_data_bool=False,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '7.2284700050169235,0.7727603709615329,675.355960843836,1.357147723895408,0.09007057474896561,3.49'
#                     '91584763075876,0.06450339776757016,0.00578156763738029'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-10-01T00:00:00Z',
#                     end_time='1998-11-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='01620500_lump_cida_forcing_leap.txt',
#                     pr='HBV_forcing_CAMELS_2024-03-12 15_13.nc',
#                     pev='HBV_forcing_CAMELS_2024-03-12 15_13.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240312_141334/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1998-11-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='01620500_lump_cida_forcing_leap.txt',
#                 pr='HBV_forcing_CAMELS_2024-03-12 15_13.nc',
#                 pev='HBV_forcing_CAMELS_2024-03-12 15_13.nc',
#                 alpha=1.26,
#                 test_data_bool=False,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '7.159201163411555,0.6977607714267868,456.85307641517835,3.3384629780412864,0.05582526437171923,1.'
#                     '8801648958886203,0.030780170255985673,0.003931084147648367'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-10-01T00:00:00Z',
#                     end_time='1998-11-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='01620500_lump_cida_forcing_leap.txt',
#                     pr='HBV_forcing_CAMELS_2024-03-12 15_13.nc',
#                     pev='HBV_forcing_CAMELS_2024-03-12 15_13.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240312_141336/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1998-11-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='01620500_lump_cida_forcing_leap.txt',
#                 pr='HBV_forcing_CAMELS_2024-03-12 15_13.nc',
#                 pev='HBV_forcing_CAMELS_2024-03-12 15_13.nc',
#                 alpha=1.26,
#                 test_data_bool=False,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '4.88126590465925,0.9937278651428749,303.8218115448266,0.8251180381938927,0.2983184943664264,5.533'
#                     '980003621176,0.05638495636088267,0.005752379045812199'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-10-01T00:00:00Z',
#                     end_time='1998-11-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='01620500_lump_cida_forcing_leap.txt',
#                     pr='HBV_forcing_CAMELS_2024-03-12 15_13.nc',
#                     pev='HBV_forcing_CAMELS_2024-03-12 15_13.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240312_141338/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1998-11-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='01620500_lump_cida_forcing_leap.txt',
#                 pr='HBV_forcing_CAMELS_2024-03-12 15_13.nc',
#                 pev='HBV_forcing_CAMELS_2024-03-12 15_13.nc',
#                 alpha=1.26,
#                 test_data_bool=False,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '7.833091798565685,0.7009374472597527,602.3958459155523,2.42564280981059,0.004332521020040876,2.89'
#                     '3799307306076,0.08536165991117263,0.008055495834728853'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-10-01T00:00:00Z',
#                     end_time='1998-11-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='01620500_lump_cida_forcing_leap.txt',
#                     pr='HBV_forcing_CAMELS_2024-03-12 15_13.nc',
#                     pev='HBV_forcing_CAMELS_2024-03-12 15_13.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240312_141339/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1998-11-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='01620500_lump_cida_forcing_leap.txt',
#                 pr='HBV_forcing_CAMELS_2024-03-12 15_13.nc',
#                 pev='HBV_forcing_CAMELS_2024-03-12 15_13.nc',
#                 alpha=1.26,
#                 test_data_bool=False,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '3.124157846309357,0.8819893268541537,514.2416908533419,0.8657728469333914,0.2958234114583239,6.32'
#                     '237533885745,0.09157025531777413,0.0015636336126286867'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-10-01T00:00:00Z',
#                     end_time='1998-11-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='01620500_lump_cida_forcing_leap.txt',
#                     pr='HBV_forcing_CAMELS_2024-03-12 15_13.nc',
#                     pev='HBV_forcing_CAMELS_2024-03-12 15_13.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240312_141341/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1998-11-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='01620500_lump_cida_forcing_leap.txt',
#                 pr='HBV_forcing_CAMELS_2024-03-12 15_13.nc',
#                 pev='HBV_forcing_CAMELS_2024-03-12 15_13.nc',
#                 alpha=1.26,
#                 test_data_bool=False,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '7.521819046916154,0.8640648310426957,702.1562373614812,1.8180691385004728,0.21265804042466757,3.8'
#                     '756795439254352,0.04260073233071028,0.009244439802954555'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-10-01T00:00:00Z',
#                     end_time='1998-11-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='01620500_lump_cida_forcing_leap.txt',
#                     pr='HBV_forcing_CAMELS_2024-03-12 15_13.nc',
#                     pev='HBV_forcing_CAMELS_2024-03-12 15_13.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240312_141342/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#         EnsembleMember(
#             model_name='HBV',
#             forcing=HBVForcing(
#                 start_time='1997-10-01T00:00:00Z',
#                 end_time='1998-11-01T00:00:00Z',
#                 directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                 shape=None,
#                 camels_file='01620500_lump_cida_forcing_leap.txt',
#                 pr='HBV_forcing_CAMELS_2024-03-12 15_13.nc',
#                 pev='HBV_forcing_CAMELS_2024-03-12 15_13.nc',
#                 alpha=1.26,
#                 test_data_bool=False,
#             ),
#             setup_kwargs={
#                 'parameters': (
#                     '3.7206104683892516,0.38705603336713845,507.3486844170203,3.079548750708498,0.2560785562729892,8.7'
#                     '914564647977,0.0689689105793674,0.007523756714392741'
#                 ),
#                 'initial_storage': '0,100,0,5',
#             },
#             state_vector_variables='all',
#             model=HBV(
#                 parameter_set=None,
#                 forcing=HBVForcing(
#                     start_time='1997-10-01T00:00:00Z',
#                     end_time='1998-11-01T00:00:00Z',
#                     directory=PosixPath('/home/davidhaasnoot/eWaterCycle-WSL-WIP/Forcing'),
#                     shape=None,
#                     camels_file='01620500_lump_cida_forcing_leap.txt',
#                     pr='HBV_forcing_CAMELS_2024-03-12 15_13.nc',
#                     pev='HBV_forcing_CAMELS_2024-03-12 15_13.nc',
#                     alpha=1.26,
#                     test_data_bool=False,
#                 ),
#             ),
#             config='/home/davidhaasnoot/eWaterCycle-WSL-WIP/hbv_20240312_141344/HBV_config.json',
#             state_vector=None,
#             variable_names=[
#                 'Imax',
#                 'Ce',
#                 'Sumax',
#                 'Beta',
#                 'Pmax',
#                 'Tlag',
#                 'Kf',
#                 'Ks',
#                 'Si',
#                 'Su',
#                 'Sf',
#                 'Ss',
#             ],
#         ),
#     ],
#     ensemble_method=None,
#     observed_variable_name=None,
#     observations=None,
#     logger=[],
# )

# %% [markdown]
# if fails to initialize, run in cmd:
# [link1](https://stackoverflow.com/questions/65272764/ports-are-not-available-listen-tcp-0-0-0-0-50070-bind-an-attempt-was-made-to)
# [link2](https://asheroto.medium.com/docker-error-an-attempt-was-made-to-access-a-socket-in-a-way-forbidden-by-its-access-permissions-15a444ab217b)
# ```bash
# net stop winnat
# netsh int ipv4 set dynamic tcp start=49152 num=16384
# netsh int ipv6 set dynamic tcp start=49152 num=16384
# net start winnat
# ````

# %%
# # #### run if fails 
# ensemble.finalize()

# %% [markdown]
# ## Import observations

# %%
# create a reference model
ref_model = ensemble.ensemble_list[0].model
ds = xr.open_dataset(forcing_path / ref_model.forcing.pr)

# %%
observations = observations_path / f'0{HRU_id}_streamflow_qc.txt'

# %%
cubic_ft_to_cubic_m = 0.0283168466

# %% [markdown]
# Load camels observation file and write to a netcdf file

# %%
new_header = ['GAGEID','Year','Month', 'Day', 'Streamflow(cubic feet per second)','QC_flag']
new_header_dict = dict(list(zip(range(len(new_header)),new_header)))

df_Q = pd.read_fwf(observations,delimiter=' ',encoding='utf-8',header=None)
df_Q = df_Q.rename(columns=new_header_dict)
df_Q['Streamflow(cubic feet per second)'] = df_Q['Streamflow(cubic feet per second)'].apply(lambda x: np.nan if x==-999.00 else x)
df_Q['Q (m3/s)'] = df_Q['Streamflow(cubic feet per second)'] * cubic_ft_to_cubic_m
df_Q['Q'] = df_Q['Q (m3/s)'] / ds.attrs['area basin(m^2)'] * 3600 * 24 * 1000 # m3/s -> m/s ->m/d -> mm/d
df_Q.index = df_Q.apply(lambda x: pd.Timestamp(f'{int(x.Year)}-{int(x.Month)}-{int(x.Day)}'),axis=1)
df_Q.index.name = "time"
df_Q.drop(columns=['Year','Month', 'Day','Streamflow(cubic feet per second)'],inplace=True)
df_Q = df_Q.dropna(axis=0)

ds_obs_dir = observations_path / f'0{HRU_id}_streamflow_qc.nc'
if not ds_obs_dir.exists():
    ds_obs = xr.Dataset(data_vars=df_Q[['Q']])
    ds_obs.to_netcdf(ds_obs_dir)

# %%
ax = df_Q['Q'].plot()
ax.set_xlim((pd.Timestamp(experiment_start_date),pd.Timestamp(experiment_end_date)))
ax.set_ylabel("Q (mm/d)")
ax.set_title("observations");

# %% [markdown]
# ## setup DA

# %% [markdown]
# This sets up all the require data assimilation information

# %%
ensemble.initialize_method(ensemble_method_name = "PF", 
                           observation_path = ds_obs_dir,
                           observed_variable_name = "Q",
                           hyper_parameters = {
                                               'like_sigma_weights' : 0.05,
                                               'like_sigma_state_vector' : 0.005,
                                               }
                            )

# %% [markdown]
# ## Run

# %%
start = datetime.now()
time = []
lst_state_vector = []
lst_Q = [] 
while ref_model.time < ref_model.end_time:
    
    lag_vector_lst = []
    for m_index, ensembleMember in enumerate(ensemble.ensemble_list):        
        ## get the memory vector - leave this for now? 
        t_lag = int(ensembleMember.get_value(f"Tlag")[0])
        lag_vector_lst.append(np.array([ensembleMember.get_value(f"memory_vector{i}") for i in range(t_lag)]).flatten())
    
    time.append(pd.Timestamp(ref_model.time_as_datetime.date()))
    ensemble.update()
    lst_state_vector.append(ensemble.get_state_vector())
    lst_Q.append(ensemble.get_value("Q"))
    
    update the parameters & states
    for index, ensembleMember in enumerate(ensemble.ensemble_list):
        # TODO: adjust so that tLag cant go to 0
        new_tlag = ensembleMember.get_value(f"Tlag")
        [ensembleMember.set_value(f"memory_vector{mem_index}", np.array([lag_vector_lst[index][mem_index]])) for mem_index in range(int(new_tlag))]

# end model - IMPORTANT! when working with dockers
ensemble.finalize()

end = datetime.now()
run = end - start
print(f'{run.seconds//60}min,{run.seconds%60}sec')
# Out:
# 7min,35sec

# %%
state_vector_over_time = np.vstack(lst_state_vector)

# %%
plt.plot(time,lst_Q)
df_Q['Q'].loc[time].plot(marker='.',lw=0,color='k')
# Out:
# <Axes: xlabel='time'>

# %%
plt.plot(state_vector_over_time[:,11])

# %% [markdown]
# ## TODO: improve data handeling
# ### process the numpy data into easily acessed data types

# %%
save, load = True, False
current_time = str(datetime.now())[:-10].replace(":","_")

# %%
if not load:
    df_ensemble = pd.DataFrame(data=Q_m_arr[:,:len(time)].T,index=time,columns=[f'particle {n}' for n in range(n_particles)])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 2
#       1 if not load:
# ----> 2     df_ensemble = pd.DataFrame(data=Q_m_arr[:,:len(time)].T,index=time,columns=[f'particle {n}' for n in range(n_particles)])
#
# NameError: name 'Q_m_arr' is not defined

# %% [markdown]
# ### process states and parameters into xarrys

# %%
##### Save? 
if save:
    df_ensemble.to_feather(output_path /f'df_ensemble_{current_time}.feather')
if load:
    df_ensemble = pd.read_feather(glob.glob(str(output_path/'df_ensemble_*.feather'))[-1]) # read last

# %%
# if load:
# TODO: obtain from model 
units= {"Imax":"mm",
        "Ce": "-",
        "Sumax": "mm",
        "Beta": "-",
        "Pmax": "mm",
        "Tlag": "d",
        "Kf": "-",
        "Ks": "-",
        "Si": "mm",
        "Su": "mm",
        "Sf": "mm",
        "Ss": "mm",
        "Ei_dt": "mm/d",
        "Ea_dt": "mm/d",
        "Qs_dt": "mm/d",
        "Qf_dt": "mm/d",
        "Q_tot_dt": "mm/d",
        "Q_m": "mm/d"}

# %%
if not load:
    # combine the 3D numpy arr into one dataArray
    storage_terms_ds = xr.DataArray(storage_terms_arr,dims=["EnsembleMember","time","storage"],
                                    coords=[np.arange(n_particles),df_ensemble.index,stor_names],
                                    attrs={"title": f"HBV storage terms data over time for {n_particles} particles ", 
                                           "history": f"Storage term results from ewatercycle_HBV.model",
                                        "description":"Moddeled storage",
                                             "units": "mm"})
    
    parameter_terms_ds = xr.DataArray(parameter_terms_arr,dims=["EnsembleMember","time","parameter"],
                                coords=[np.arange(n_particles),df_ensemble.index,param_names],
                                    attrs={"title": f"HBV storage terms data over time for {n_particles} particles ", 
                                           "history": f"Storage terms results from ewatercycle_HBV.model",})
    
    # even better is to combine into one Data_set_- this is most intuitive way for me - probably more ways
    data_vars = {}
    for i, name in enumerate(stor_names):
        storage_terms_i = xr.DataArray(storage_terms_arr[:,:,i],
                                       name=name,
                                       dims=["EnsembleMember","time"],
                                      coords=[np.arange(n_particles),df_ensemble.index],
                                      attrs={"title": f"HBV storage terms data over time for {n_particles} particles ", 
                                               "history": f"Storage term results from ewatercycle_HBV.model",
                                            "description":"Moddeled storage",
                                                 "units": "mm"})
        data_vars[name] = storage_terms_i
    for i, name in enumerate(param_names):
        storage_terms_i = xr.DataArray(parameter_terms_arr[:,:,i],
                                       name=name,
                                       dims=["EnsembleMember","time"],
                                      coords=[np.arange(n_particles),df_ensemble.index],
                                      attrs={"title": f"HBV storage terms data over time for {n_particles} particles ", 
                                               "history": f"Storage term results from ewatercycle_HBV.model",
                                            "description":"Moddeled storage",
                                                 "units": units[name]})
        data_vars[name] = storage_terms_i

    ds_combined = xr.Dataset(data_vars,
                             attrs={"title": f"HBV storage terms data over time for {n_particles} particles ", 
                                    "history": f"Storage term results from ewatercycle_HBV.model",}
                              )

# %%
##### Save? 
if save:
    storage_terms_ds.to_netcdf(output_path / f'storage_terms_ds_{current_time}.nc')
    parameter_terms_ds.to_netcdf(output_path / f'parameter_terms_ds_{current_time}.nc')
    ds_combined.to_netcdf(output_path / f'combined_ds_{current_time}.nc')
    
if load:
    storage_terms_ds = xr.open_dataarray(glob.glob(str(output_path / r'storage_terms_ds_*.nc'))[-1])
    parameter_terms_ds = xr.open_dataarray(glob.glob(str(output_path / 'parameter_terms_ds_*.nc'))[-1])
    ds_combined = xr.open_dataset(glob.glob(str(output_path / 'combined_ds_*.nc'))[-1])

# %% [markdown]
# # Plotting

# %%
# df_ensemble.plot()
fig, ax = plt.subplots(1,1,figsize=(12,5))
# ax.plot(ds.time.values[:n_days],ds['Q'].values[:n_days],lw=0,marker="*",ms=2.5,zorder=0,label="Observations",color="k")
# ax.plot(df.index, Q_m_in_ref[1:],label="Modelled reference Q");
df_Q.loc[Q_obs_t_lst,"Q"].plot(ax=ax,lw=0,marker="*",ms=2.5,zorder=0,label="Observations",color='k')
ax.legend(bbox_to_anchor=(1,1))
df_ensemble.plot(ax=ax,alpha=0.5,zorder=-1,legend=False)
ax.set_ylabel("Q [mm]")
ax.set_title(f"Run ensemble of {n_particles} particles");
ax.set_xlim((pd.Timestamp('1997-08-01'),pd.Timestamp('1998-12-01')))
ax.set_ylim((0,10))
if save:
    fig.savefig(figure_path / f"ensemble_run_for_{n_particles}_particles_{current_time}.png")

# %% [markdown]
# Can calculate the mean of 50 particles as a reference

# %%
mean_ensemble = df_ensemble.T.mean()
NSE_mean_ens = calc_NSE(df_Q.loc[time,"Q"],mean_ensemble.loc[time])

# %%
# df_ensemble.plot()
fig, ax = plt.subplots(1,1,figsize=(12,5))
# ax.plot(ds.time.values[:n_days],ds['Q'].values[:n_days],lw=0,marker="*",ms=2.5,zorder=0,label="Observations",color="k")
# ax.plot(df.index, Q_m_in_ref[1:],label="Modelled reference Q");
df_Q.loc[Q_obs_t_lst,"Q"].plot(ax=ax,lw=0,marker="*",ms=2.0,zorder=0,label="Observations",color='k')

ax.plot(mean_ensemble,color="C1",lw=0.5,label=f"mean {NSE_mean_ens:.2f}",zorder=-1)
ax.fill_between(df_ensemble.index,df_ensemble.T.min(),df_ensemble.T.max(),color="C0", alpha=0.35,zorder=-10,label="bounds")
ax.legend(bbox_to_anchor=(1.25,1))
ax.set_ylabel("Q [mm]")
ax.set_title(f"Run ensemble of {n_particles} particles");
# ax.set_xlim((pd.Timestamp('1997-08-01'),pd.Timestamp('1998-06-01')))
if save:
    fig.savefig(figure_path / f"ensemble_run_for_{n_particles}_particles_{current_time}.png",bbox_inches="tight",dpi=400);

# %%
# df_ensemble.plot()
fig, ax = plt.subplots(1,1,figsize=(12,5))
# ax.plot(ds.time.values[:n_days],ds['Q'].values[:n_days],lw=0,marker="*",ms=2.5,zorder=0,label="Observations",color="k")
# ax.plot(df.index, Q_m_in_ref[1:],label="Modelled reference Q");
df_Q.loc[Q_obs_t_lst,"Q"].plot(ax=ax,lw=0,marker="*",ms=2.0,zorder=0,label="Observations",color='k')

ax_pr = ax.twinx()
ax_pr.invert_yaxis()
ax_pr.set_ylabel(f"P [mm]")
ax_pr.bar(df_ensemble.index,ds['pr'].values[:n_timesteps],zorder=-15,label="Precipitation",color="grey")
ax_pr.legend(bbox_to_anchor=(1.25,0.8))

ax.plot(mean_ensemble,color="C1",lw=0.5,label=f"mean",zorder=-1)
ax.fill_between(df_ensemble.index,df_ensemble.T.min(),df_ensemble.T.max(),color="C0", alpha=0.35,zorder=-10,label="bounds")
ax.legend(bbox_to_anchor=(1.25,1))
ax.set_ylabel("Q [mm]")
ax.set_title(f"Run ensemble of {n_particles} particles");
if save:
    fig.savefig(figure_path / f"ensemble_run_for_{n_particles}_particles_bounds_P_{current_time}.png",bbox_inches="tight",dpi=400);

# %%
n=5
fig, axs = plt.subplots(n,1,figsize=(12,n*2),sharex=True)

ax = axs[0]
df_Q.loc[Q_obs_t_lst,"Q"].plot(ax=ax,lw=0,marker="*",ms=2.5,zorder=0,label="Observations",color='k')
ax_pr = ax.twinx()
ax_pr.invert_yaxis()
ax_pr.set_ylabel(f"P [mm]")
ax_pr.bar(df_ensemble.index,ds['pr'].values[:n_timesteps],zorder=-10,label="Precipitation",color="grey")

ax.plot(mean_ensemble,color="C1",lw=0.5,label=f"mean",zorder=-1)
ax.fill_between(df_ensemble.index,df_ensemble.T.min(),df_ensemble.T.max(),color="C0", alpha=0.5,zorder=-10,label="bounds")
ax.legend(bbox_to_anchor=(1.25,1))
ax.set_ylabel("Q [mm]")

ax.set_title(f"Run ensemble of {n_particles} particles");

for i, S_name in enumerate(S_names):
    for j in range(n_particles):
        storage_terms_ds.isel(storage=i,EnsembleMember=j).plot(ax=axs[i+1],color=f"C{i}",alpha=0.5)
        axs[i+1].set_title(S_name)

# remove all unncecearry xlabels
[ax.set_xlabel(None) for ax in axs[:-1]]
[ax.set_ylabel("S [mm]") for ax in axs[1:]]
if save:
    fig.savefig(figure_path / f"ensemble_run_for__{n_particles}_particles_storages_{current_time}.png",bbox_inches="tight",dpi=400)

# %%
fig, ax = plt.subplots(1,1)
for i in range(n_particles):
    storage_terms_ds.sel(storage="Ss").isel(EnsembleMember=i).plot(ax=ax)

# %%
fig, ax = plt.subplots(1,1)

parameter="Tlag"
for i in range(n_particles):
    parameter_terms_ds.sel(parameter=parameter).isel(EnsembleMember=i).plot(ax=ax)
ax.set_title(f'parameter={parameter} for {n_particles} Ensemble Members')

# %%
fig, axs = plt.subplots(2,4,figsize=(25,10),sharex=True)
axs = axs.flatten()
for j, parameter in enumerate(param_names):
    ax = axs[j]
    for i in range(n_particles):
        parameter_terms_ds.sel(parameter=parameter).isel(EnsembleMember=i).plot(ax=ax,alpha=0.3)
    ax.set_title(f'parameter={parameter}')# for {n_particles} Ensemble Members')
    ax.set_ylabel(f'[{units[parameter]}]')
if save:
    fig.savefig(figure_path /  f"ensemble_run_for__{n_particles}_particles_parameters_{current_time}.png",bbox_inches="tight",dpi=400)
